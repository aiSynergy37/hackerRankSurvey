# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import pandas.tools.plotting
import seaborn as sns
import matplotlib


# %matplotlib inline

plt.style.use('seaborn')

# %% [markdown]
# # Import Data and Get an Overview

# %%
codebook=pd.read_csv('C:/Users/VarunTarun/AppData/Local/Temp/Temp1_developer-survey-2018.zip/HackerRank-Developer-Survey-2018-Codebook.csv')

# %%
codebook.head()
# Out:
#          Data Field                   Survey Question  \
# 0      RespondentID                               NaN
# 1         StartDate                               NaN
# 2           EndDate                               NaN
# 3   CountryNumeric2                               NaN
# 4  q1AgeBeginCoding  At what age did you start coding
#
#                                  Notes
# 0                        Respondent ID
# 1  When did they start (date and time)
# 2    When did they end (date and time)
# 3         see Country-Code-Mapping.csv
# 4                                  NaN

# %%
codebook.size
# Out:
# 753

# %%
codebook.tail()
# Out:
#                      Data Field  \
# 246    q33HackerRankChallforJob
# 247              q34PositiveExp
# 248  q34IdealLengHackerRankTest
# 249                 q0035_other
# 250                   q36Level4
#
#                                        Survey Question  \
# 246  Have you ever taken a HackerRank challenge as ...
# 247                  How positive was your experience?
# 248  What do you think is the ideal length of a Hac...
# 249                             Other (please specify)
# 250  Which of the following is useful in traversing...
#
#                                                  Notes
# 246                                                NaN
# 247  Shown if q33HackerRankChallforJob == Yes; rati...
# 248           Shown if q33HackerRankChallforJob == Yes
# 249                                                NaN
# 250                           right answer: 2 or Queue

# %%
numeric_mapping=pd.read_csv('C:/Users/VarunTarun/AppData\Local/Temp/Temp1_developer-survey-2018.zip/HackerRank-Developer-Survey-2018-Numeric-Mapping.csv')

# %%
numeric_mapping.head()
# Out:
#          Data Field  Value              Label
# 0  q1AgeBeginCoding      1   5 - 10 years old
# 1  q1AgeBeginCoding      2  11 - 15 years old
# 2  q1AgeBeginCoding      3  16 - 20 years old
# 3  q1AgeBeginCoding      4  21 - 25 years old
# 4  q1AgeBeginCoding      5  26 - 30 years old

# %%
numeric_mapping.size
# Out:
# 1356

# %%
numeric_mapping.tail()
# Out:
#                      Data Field  Value         Label
# 447  q34IdealLengHackerRankTest      3    1 -2 hours
# 448  q34IdealLengHackerRankTest      4  2 to 4 hours
# 449                   q36Level4      1           Set
# 450                   q36Level4      2         Queue
# 451                   q36Level4      3       Hashmap

# %%
numeric = pd.read_csv('C:/Users/VarunTarun/AppData/Local/Temp/Temp1_developer-survey-2018.zip/HackerRank-Developer-Survey-2018-Numeric.csv')
# Out:
# C:\Users\VarunTarun\Downloads\anaconda678679\lib\site-packages\IPython\core\interactiveshell.py:2785: DtypeWarning: Columns (10,19,137,138,250) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
numeric.size
# Out:
# 6297590

# %%
numeric.head()
# Out:
#    RespondentID       StartDate         EndDate  CountryNumeric2  \
# 0    6464453728  10/19/17 11:51  10/20/17 12:05            148.0
# 1    6478031510   10/26/17 6:18   10/26/17 7:49            164.0
# 2    6464392829  10/19/17 10:44  10/19/17 10:56             98.0
# 3    6481629912   10/27/17 1:51   10/27/17 2:05             43.0
# 4    6488385057  10/31/17 11:46  10/31/17 11:59              NaN
#
#   q1AgeBeginCoding q2Age q3Gender q4Education q0004_other q5DegreeFocus  \
# 0                3     3        2           3         NaN             1
# 1                3     4        1           7         NaN             2
# 2                2     2        2           3         NaN             2
# 3                2     2        1           5         NaN             1
# 4                3     4        2           5         NaN             0
#
#      ...    q30LearnCodeOther                         q0030_other  q31Level3  \
# ...

# %%
numeric.tail()
# Out:
#        RespondentID      StartDate        EndDate  CountryNumeric2  \
# 25085    6490801288  11/1/17 10:36  11/1/17 10:45              NaN
# 25086    6490929806  11/1/17 11:20  11/1/17 11:35              NaN
# 25087    6489517004  11/1/17 12:05  11/1/17 12:11              NaN
# 25088    6489519290  11/1/17 12:07  11/1/17 12:25              NaN
# 25089    6489540090  11/1/17 12:30  11/1/17 12:39              NaN
#
#       q1AgeBeginCoding q2Age q3Gender q4Education        q0004_other  \
# 25085                3     3        1           5                NaN
# 25086                2     3        1           3                NaN
# 25087                1     2        1           2                NaN
# 25088                3     3        1      #NULL!  Doing Engineering
# 25089                4     3        1           5                NaN
#
#       q5DegreeFocus    ...    q30LearnCodeOther  q0030_other  q31Level3  \
# ...

# %%
values = pd.read_csv('C:/Users/VarunTarun/AppData/Local/Temp/Temp1_developer-survey-2018.zip/HackerRank-Developer-Survey-2018-Values.csv', na_values=['#NULL!', 'nan'])
# Out:
# C:\Users\VarunTarun\Downloads\anaconda678679\lib\site-packages\IPython\core\interactiveshell.py:2785: DtypeWarning: Columns (3,10,19,137,138) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
values.size
# Out:
# 6297590

# %%
values.head()
# Out:
#    RespondentID       StartDate         EndDate CountryNumeric2  \
# 0    6464453728  10/19/17 11:51  10/20/17 12:05     South Korea
# 1    6478031510   10/26/17 6:18   10/26/17 7:49         Ukraine
# 2    6464392829  10/19/17 10:44  10/19/17 10:56        Malaysia
# 3    6481629912   10/27/17 1:51   10/27/17 2:05         Curaçao
# 4    6488385057  10/31/17 11:46  10/31/17 11:59             NaN
#
#     q1AgeBeginCoding              q2Age q3Gender  \
# 0  16 - 20 years old  18 - 24 years old   Female
# 1  16 - 20 years old  25 - 34 years old     Male
# 2  11 - 15 years old  12 - 18 years old   Female
# 3  11 - 15 years old  12 - 18 years old     Male
# 4  16 - 20 years old  25 - 34 years old   Female
#
#                            q4Education q0004_other  \
# 0                         Some college         NaN
# 1  Post graduate degree (Masters, PhD)         NaN
# 2                         Some college         NaN
# 3                     College graduate         NaN
# ...

# %%
values.tail()
# Out:
#        RespondentID      StartDate        EndDate CountryNumeric2  \
# 25085    6490801288  11/1/17 10:36  11/1/17 10:45             NaN
# 25086    6490929806  11/1/17 11:20  11/1/17 11:35             NaN
# 25087    6489517004  11/1/17 12:05  11/1/17 12:11             NaN
# 25088    6489519290  11/1/17 12:07  11/1/17 12:25             NaN
# 25089    6489540090  11/1/17 12:30  11/1/17 12:39             NaN
#
#         q1AgeBeginCoding              q2Age q3Gender           q4Education  \
# 25085  16 - 20 years old  18 - 24 years old     Male      College graduate
# 25086  11 - 15 years old  18 - 24 years old     Male          Some college
# 25087   5 - 10 years old  12 - 18 years old     Male  High school graduate
# 25088  16 - 20 years old  18 - 24 years old     Male                   NaN
# 25089  21 - 25 years old  18 - 24 years old     Male      College graduate
#
#              q0004_other     q5DegreeFocus    ...    q30LearnCodeOther  \
# ...

# %%
print(values.columns.ravel())
# Out:
# ['RespondentID' 'StartDate' 'EndDate' 'CountryNumeric2' 'q1AgeBeginCoding'
#  'q2Age' 'q3Gender' 'q4Education' 'q0004_other' 'q5DegreeFocus'
#  'q0005_other' 'q6LearnCodeUni' 'q6LearnCodeSelfTaught'
#  'q6LearnCodeAccelTrain' 'q6LearnCodeDontKnowHowToYet' 'q6LearnCodeOther'
#  'q0006_other' 'q7Level1' 'q8JobLevel' 'q0008_other' 'q8Student'
#  'q9CurrentRole' 'q0009_other' 'q10Industry' 'q0010_other'
#  'q12JobCritPrefTechStack' 'q12JobCritCompMission' 'q12JobCritCompCulture'
#  'q12JobCritWorkLifeBal' 'q12JobCritCompensation' 'q12JobCritProximity'
#  'q12JobCritPerks' 'q12JobCritSmartPeopleTeam'
#  'q12JobCritImpactwithProduct' 'q12JobCritInterestProblems'
#  'q12JobCritFundingandValuation' 'q12JobCritStability'
#  'q12JobCritProfGrowth' 'q12JobCritOther' 'q0012_other'
#  'q13EmpMeasWhiteboard' 'q13EmpMeasHackerRank'
#  'q13EmpMeasOtherCodingChallenge' 'q13EmpMeasTechPhoneInt'
#  'q13EmpMeasTakeHomeProject' 'q13EmpMeasResume' 'q13EmpMeasPastWork'
# ...

# %%
def draw_heatmap(column1, column2, title=None, annot=True, ax=None, size=(10, 10), data=values):
    cross = pd.crosstab(data[column1], data[column2])
    
    if ax is None:
        f, ax = plt.subplots(figsize=size)
        
    sns.heatmap(cross, cmap='Reds', annot=annot, ax=ax)
    ax.set_ylabel(codebook.loc[column1]['question'])
    ax.set_xlabel(codebook.loc[column2]['question'])
    
    if title is not None:
        ax.set_title(title)

# %%
numeric.loc[numeric['q1AgeBeginCoding'] == -1, 'q1AgeBeginCoding'] = 0
numeric.loc[numeric['q2Age'] == -1, 'q2Age'] = 0

# %%
numeric_mapping.loc['q2Age'] = [[i+1, j] for i, j in zip(range(9), ['Under 12', '12 - 18', '18 - 24', '25 - 34', '35 - 44', '45 - 54', '55 - 64', '65 - 74', '75+'])]
numeric_mapping.loc['q1AgeBeginCoding'] = numeric_mapping.loc['q1AgeBeginCoding'].applymap(lambda x: str(x).replace('years old', ''))
